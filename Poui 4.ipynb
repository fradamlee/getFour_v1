# %%
#Bienvenido

# %%
import random
from IPython.display import clear_output

def screen(board):
    '''
    Esta función sirve para mostrar visualmente el tablero, solo pide como input el tablero actual(una lista con las 64 casillas con sus respectivos valores)
    '''
    new_winner = False
    clear_output()
    print(' 1', ' 2', ' 3', ' 4', ' 5', ' 6', ' 7', ' 8')
    print('|' + board[8] + ' ' + '|' + board[28] + ' ' + '|' + board[48] + ' ' + '|' + board[68] + ' ' + '|' + board[88] + ' ' + '|' + board[108] + ' ' + '|' + board[128] + ' ' + '|' + board[148] + ' ' + '|')
    print('------------------------')
    print('|' + board[7] + ' ' + '|' + board[27] + ' ' + '|' + board[47] + ' ' + '|' + board[67] + ' ' + '|' + board[87] + ' ' + '|' + board[107] + ' ' + '|' + board[127] + ' ' + '|' + board[147] + ' ' + '|')
    print('------------------------')

    print('|' + board[6] + ' ' + '|' + board[26] + ' ' + '|' + board[46] + ' ' + '|' + board[66] + ' ' + '|' + board[86] + ' ' + '|' + board[106] + ' ' + '|' + board[126] + ' ' + '|' + board[146] + ' ' + '|')
    print('------------------------')
    print('|' + board[5] + ' ' + '|' + board[25] + ' ' + '|' + board[45] + ' ' + '|' + board[65] + ' ' + '|' + board[85] + ' ' + '|' + board[105] + ' ' + '|' + board[125] + ' ' + '|' + board[145] + ' ' + '|')
    print('------------------------')
    print('|' + board[4] + ' ' + '|' + board[24] + ' ' + '|' + board[44] + ' ' + '|' + board[64] + ' ' + '|' + board[84] + ' ' + '|' + board[104] + ' ' + '|' + board[124] + ' ' + '|' + board[144] + ' ' + '|')
    print('------------------------')
    print('|' + board[3] + ' ' + '|' + board[23] + ' ' + '|' + board[43] + ' ' + '|' + board[63] + ' ' + '|' + board[83] + ' ' + '|' + board[103] + ' ' + '|' + board[123] + ' ' + '|' + board[143] + ' ' + '|')
    print('------------------------')

    print('|' + board[2] + ' ' + '|' + board[22] + ' ' + '|' + board[42] + ' ' + '|' + board[62] + ' ' + '|' + board[82] + ' ' + '|' + board[102] + ' ' + '|' + board[122] + ' ' + '|' + board[142] + ' ' + '|')
    print('------------------------')
    print('|' + board[1] + ' ' + '|' + board[21] + ' ' + '|' + board[41] + ' ' + '|' + board[61] + ' ' + '|' + board[81] + ' ' + '|' + board[101] + ' ' + '|' + board[121] + ' ' + '|' + board[141] + ' ' + '|')
    print('------------------------')

# %%
states = [8, 28, 48, 68, 88, 108, 128, 148, 7, 27, 47, 67, 87, 107, 127, 147, 6, 26, 46, 66, 86, 106, 126, 146, 5, 25, 45, 65, 85, 105, 125, 145, 4, 24, 44, 64, 84, 104, 124, 144, 3, 23, 43, 63, 83, 103, 123, 143, 2, 22, 42, 62, 82, 102, 122, 142, 1, 21, 41, 61, 81, 101, 121, 141]

# %%
def start():
    static_var.board = ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
    static_var.roun = 0
    static_var.the_marker(static_var.board)

# %%
class Static_Var():
    '''
    Esta es tal vez la peor practica,
    fue creado como solución rápida para conservar o guardar los cambios realizados a las variables
    '''
    def __init__(self):
        self.the_end = None
        self.roun = 0
        self.start_comp = False
        self.board = ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
        self.board_scene = ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
        self.computer = 'X'
        self.player = 'O'
    def cicle_or_cross(self):
        self.go_first = random.randint(0, 1)
        self.bol = random.randint(0, 1)
        if 0 == self.bol:
            self.sign_1 = 'X'
            self.sign_2 = 'O'
        else:
            self.sign_1 = 'O'
            self.sign_2 = 'X'
        if self.go_first == 0:
            print(f'Computer starts with {self.sign_1}')
            self.computer = self.sign_1
            self.player = self.sign_2
            static_var.start_comp = True
        else:
            print(f'Player starts with {self.sign_1}')
            self.computer = self.sign_2 
            self.player = self.sign_1
    
    def the_marker(self, board):
        '''
        Este método devuelve todas las líneas validas en las que se puede ganar con sus respectivos valores, solo pide como input el tablero actual
        '''
        return [[self.board [1], self.board [2], self.board [3], self.board [4], self.board [5], self.board [6], self.board [7], self.board [8]],
         [self.board [21], self.board [22], self.board [23], self.board [24], self.board [25], self.board [26], self.board [27], self.board [28]], 
         [self.board [41], self.board [42], self.board [43], self.board [44], self.board [45], self.board [46], self.board [47], self.board [48]],
         [self.board [61], self.board [62], self.board [63], self.board [64], self.board [65], self.board [66], self.board [67], self.board [68]],
         [self.board [81], self.board [82], self.board [83], self.board [84], self.board [85], self.board [86], self.board [87], self.board [88]],
         [self.board [101], self.board [102], self.board [103], self.board [104], self.board [105], self.board [106], self.board [107], self.board [108]],
         [self.board [121], self.board [122], self.board [123], self.board [124], self.board [125], self.board [126], self.board [127], self.board [128]],
         [self.board [141], self.board [142], self.board [143], self.board [144], self.board [145], self.board [146], self.board [147], self.board [148]],
         
         [self.board [1], self.board [21], self.board [41], self.board [61], self.board [81], self.board [101], self.board [121], self.board [141]],
         [self.board [2], self.board [22], self.board [42], self.board [62], self.board [82], self.board [102], self.board [122], self.board [142]],
         [self.board [3], self.board [23], self.board [43], self.board [63], self.board [83], self.board [103], self.board [123], self.board [143]],
         [self.board [4], self.board [24], self.board [44], self.board [64], self.board [84], self.board [104], self.board [124], self.board [144]],
         [self.board [5], self.board [25], self.board [45], self.board [65], self.board [85], self.board [105], self.board [125], self.board [145]],
         [self.board [6], self.board [26], self.board [46], self.board [66], self.board [86], self.board [106], self.board [126], self.board [146]],
         [self.board [7], self.board [27], self.board [47], self.board [67], self.board [87], self.board [107], self.board [127], self.board [147]],
         [self.board [8], self.board [28], self.board [48], self.board [68], self.board [88], self.board [108], self.board [128], self.board [148]],
          
        [self.board [81], self.board [102], self.board [123], self.board [144]],    
        [self.board [61], self.board [82], self.board [103], self.board [124], self.board [145]],
        [self.board [41], self.board [62], self.board [83], self.board [104], self.board [125], self.board [146]],
        [self.board [21], self.board [42], self.board [63], self.board [84], self.board [105], self.board [126], self.board [147]],
        [self.board [1], self.board [22], self.board [43], self.board [64], self.board [85], self.board [106], self.board [127], self.board [148]],
        [self.board [2], self.board [23], self.board [44], self.board [65], self.board [86], self.board [107], self.board [128]],
        [self.board [3], self.board [24], self.board [45], self.board [66], self.board [87], self.board [108]],
        [self.board [4], self.board [25], self.board [46], self.board [67], self.board [88]],
        [self.board [5], self.board [26], self.board [47], self.board [68]],     
        
        [self.board[4], self.board[23], self.board[42], self.board[61]],
        [self.board[5], self.board[24], self.board[43], self.board[62], self.board[81]],
        [self.board[6], self.board[25], self.board[44], self.board[63], self.board[82], self.board[101]],
        [self.board[7], self.board[26], self.board[45], self.board[64], self.board[83], self.board[102], self.board[121]],
        [self.board[8], self.board[27], self.board[46], self.board[65], self.board[84], self.board[103], self.board[122], self.board[141]],
        [self.board[28], self.board[47], self.board[66], self.board[85], self.board[104], self.board[123], self.board[142]],
        [self.board[48], self.board [67], self.board[86], self.board[105], self.board[124], self.board[143]],
        [self.board[68], self.board[87], self.board[106], self.board[125], self.board[144]],
        [self.board[88], self.board[107], self.board[126], self.board[145]]]
    
    def the_marker_scene(self, board_scene):
        '''
        Lo mismo que el anterior pero para el emulador de esenarios
        '''
        return [[self.board_scene[1], self.board_scene[2], self.board_scene[3], self.board_scene[4], self.board_scene[5], self.board_scene[6], self.board_scene [7], self.board_scene [8]],
         [self.board_scene[21], self.board_scene[22], self.board_scene[23], self.board_scene[24], self.board_scene[25], self.board_scene[26], self.board_scene [27], self.board_scene [28]], 
         [self.board_scene[41], self.board_scene[42], self.board_scene[43], self.board_scene[44], self.board_scene[45], self.board_scene[46], self.board_scene [47], self.board_scene [48]],
         [self.board_scene[61], self.board_scene[62], self.board_scene[63], self.board_scene[64], self.board_scene[65], self.board_scene[66], self.board_scene [67], self.board_scene [68]],
         [self.board_scene[81], self.board_scene[82], self.board_scene[83], self.board_scene[84], self.board_scene[85], self.board_scene[86], self.board_scene [87], self.board_scene [88]],
         [self.board_scene[101], self.board_scene[102], self.board_scene[103], self.board_scene[104], self.board_scene[105], self.board_scene[106], self.board_scene[107], self.board_scene[108]],
         [self.board_scene[121], self.board_scene[122], self.board_scene[123], self.board_scene[124], self.board_scene[125], self.board_scene[126], self.board_scene[127], self.board_scene[128]],
         [self.board_scene[141], self.board_scene[142], self.board_scene[143], self.board_scene[144], self.board_scene[145], self.board_scene[146], self.board_scene[147], self.board_scene[148]],
         
         [self.board_scene[1], self.board_scene[21], self.board_scene[41], self.board_scene[61], self.board_scene[81], self.board_scene[101], self.board_scene [121], self.board_scene[141]],
         [self.board_scene[2], self.board_scene[22], self.board_scene[42], self.board_scene[62], self.board_scene[82], self.board_scene[102], self.board_scene [122], self.board_scene [142]],
         [self.board_scene[3], self.board_scene[23], self.board_scene[43], self.board_scene[63], self.board_scene[83], self.board_scene[103], self.board_scene[123], self.board_scene[143]],
         [self.board_scene[4], self.board_scene[24], self.board_scene[44], self.board_scene[64], self.board_scene[84], self.board_scene[104], self.board_scene[124], self.board_scene[144]],
         [self.board_scene[5], self.board_scene[25], self.board_scene[45], self.board_scene[65], self.board_scene[85], self.board_scene[105], self.board_scene[125], self.board_scene[145]],
         [self.board_scene[6], self.board_scene[26], self.board_scene[46], self.board_scene[66], self.board_scene[86], self.board_scene[106], self.board_scene[126], self.board_scene[146]],
         [self.board_scene[7], self.board_scene[27], self.board_scene[47], self.board_scene[67], self.board_scene[87], self.board_scene[107], self.board_scene[127], self.board_scene[147]],
         [self.board_scene[8], self.board_scene[28], self.board_scene[48], self.board_scene[68], self.board_scene[88], self.board_scene[108], self.board_scene[128], self.board_scene[148]],
          
        [self.board_scene[81], self.board_scene[102], self.board_scene[123], self.board_scene[144]],    
        [self.board_scene[61], self.board_scene[82], self.board_scene[103], self.board_scene[124], self.board_scene[145]],
        [self.board_scene[41], self.board_scene[62], self.board_scene[83], self.board_scene[104], self.board_scene[125], self.board_scene[146]],
        [self.board_scene[21], self.board_scene[42], self.board_scene[63], self.board_scene[84], self.board_scene[105], self.board_scene[126], self.board_scene[147]],
        [self.board_scene[1], self.board_scene[22], self.board_scene[43], self.board_scene[64], self.board_scene[85], self.board_scene[106], self.board_scene[127], self.board_scene [148]],
        [self.board_scene[2], self.board_scene[23], self.board_scene[44], self.board_scene[65], self.board_scene[86], self.board_scene[107], self.board_scene[128]],
        [self.board_scene[3], self.board_scene[24], self.board_scene[45], self.board_scene[66], self.board_scene[87], self.board_scene[108]],
        [self.board_scene[4], self.board_scene[25], self.board_scene[46], self.board_scene[68]],
         
        [self.board_scene[4], self.board_scene[23], self.board_scene[42], self.board_scene[61]],
        [self.board_scene[5], self.board_scene[24], self.board_scene[43], self.board_scene[62], self.board_scene[81]],
        [self.board_scene[6], self.board_scene[25], self.board_scene[44], self.board_scene[63], self.board_scene[82], self.board_scene[101]],
        [self.board_scene[7], self.board_scene[26], self.board_scene[45], self.board_scene[64], self.board_scene[83], self.board_scene[102], self.board_scene[121]],
        [self.board_scene[8], self.board_scene[27], self.board_scene[46], self.board_scene[65], self.board_scene[84], self.board_scene[103], self.board_scene[122], self.board_scene[141]],
        [self.board_scene[28], self.board_scene[47], self.board_scene[66], self.board_scene[85], self.board_scene[104], self.board_scene[123], self.board_scene[142]],
        [self.board_scene[48], self.board_scene [67], self.board_scene[86], self.board_scene[105], self.board_scene[124], self.board_scene[143]],
        [self.board_scene[68], self.board_scene[87], self.board_scene[106], self.board_scene[125], self.board_scene[144]],
        [self.board_scene[88], self.board_scene[107], self.board_scene[126], self.board_scene[145]]]
        
    def f_roun(self):
        self.roun += 1
    def f_board(self, x, ind):
        self.x = x
        self.ind = ind
        self.board[self.ind] = self.x #+ ' '
        self.the_marker(static_var.board)
    def f_bor_scene(self, y, inde):
        self.y = y
        self.inde = inde
        self.board_scene[self.inde] = self.y #+ ' '
        self.the_marker_scene(static_var.board_scene)
    def f_start(self):
        static_var.board = ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
        static_var.roun = 0
        static_var.the_marker(static_var.board)
    def f_start_scene(self):
        static_var.board_scene = ['#', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
        static_var.the_marker(static_var.board_scene)
    def acomodate_all(self):
        self.roun = c_roun
        self.board = clear
    def loose(self):
        self.the_end = True
    def win(self):
        self.the_end = False
static_var = Static_Var()

# %%
static_var.cicle_or_cross()
# Out:
# Computer starts with X

# %%
static_var.computer
# Out:
# 'X'

# %%
def possibility(board, who):
    
    '''
SECCIÓN PROCESAMIENTO MAQUINA
Esta función es llamada por el emulador de esenarios, sirve para determinar si en el tablero actual hay un ganador
Sus inputs son (el tablero actual, qué ficha (es decir quién)) De haber un ganador devuele 1, si no devuelve 0
    '''
    
    mark = static_var.the_marker_scene(board)
    #print(board)
    #print(mark)
    
    
    the_list = [ ]
    for lst in mark:
        for ele in lst:
            #if ele in states:
            if ele == who:
                the_list.append(ele)
                if len(the_list) >= 4:

                    return 1
                    break
            else:
                the_list = [ ]
    return 0
#possibility(static_var.board_scene, 'X')

# %%
#UNION


def union(n):
    '''
UNION: SECCIÓN PROCESAMIENTO MAQUINA
Este es el emulador de escenarios, aquí se llaman todas las fuciones que participan en el proceso de ponderar una columna como mejor opción
    '''
    opcion0 = 0
    opcion1 = 0
    opcion2 = 0
    opcion3 = 0
    
    scenarios(n, static_var.board_scene, static_var.computer)
    
    #Quita los comentarios inferiores si deseas ver el emulador de escenarios tabajando
    #print(screen(static_var.board_scene)) # <----
    
    opcion0 = possibility(static_var.board_scene, static_var.computer)
    
    for ele1 in range(1, 9):
        scenarios(ele1, static_var.board_scene, static_var.player)
        
        #Quita los comentarios inferiores si deseas ver el emulador de escenarios tabajando
        #print(screen(static_var.board_scene)) # <----
        
        opcion1 += possibility(static_var.board_scene, static_var.player)
        
        for ele2 in range(1, 9):
            scenarios(ele2, static_var.board_scene, static_var.computer)
            
            #Quita los comentarios inferiores si deseas ver el emulador de escenarios tabajando
            #print(screen(static_var.board_scene)) # <----
            
            opcion2 += possibility(static_var.board_scene, static_var.computer)
            
            for ele3 in range(1, 9):
                scenarios(ele3, static_var.board_scene, static_var.player)
                
                #Quita los comentarios inferiores si deseas ver el emulador de escenarios tabajando
                #print(screen(static_var.board_scene)) # <----
                
                opcion3 += possibility(static_var.board_scene, static_var.computer)

                go_back(ele3, static_var.board_scene)
            
            go_back(ele2, static_var.board_scene)
            
        go_back(ele1, static_var.board_scene)
    
    go_back(n, static_var.board_scene)
    
    chance0 = opcion0 * 1000000000
    weakness1 = opcion1 * 100000000
    chance2 = opcion2 * 1000000
    weakness3 = opcion3 * 100000

    return ((chance0 + chance2 + 1000000000) / (weakness1 + weakness3 + 1))

# %%
def scenarios(n, boar, who):
    '''
SECCIÓN PROCESAMIENTO MAQUINA
El emulador de esenarios al llamar la función scenarios realiza una jugada los resive como input(numero de columna, el tablero actual, que ficha juega)

    '''
    
    col_1 = (n * 20) - 19
    while not boar[col_1] == ' ':#
        col_1 += 1

    else:
        boar[col_1] = who #+ ' '
        static_var.board_scene = boar

# %%
def go_back(num, board):
    '''
SECCIÓN PROCESAMIENTO MAQUINA
La función go_back tiene dos parámetros de entrada número de fila y el tablero actual(una lista con las 64 casillas con sus respectivos valores)
Está función se llama para hacer que el emulador de escenarios regrese a la normalidad déspues probar una jugada
    '''
    
    col_1 = (num * 20) - 19
    
    while not board[col_1] == ' ':#
        col_1 += 1

    else:
        col_1 -= 1
        board[col_1] = ' ' #j

# %%
def the_election():
    '''
SECCIÓN PROCESAMIENTO MAQUINA
Aquí se decide cual de las 8 columnas es la mejor decisión, en base a la que tenga la poneración más alta
    '''
    
    lst_cand = [ ]
    
    vote_1 = union(1)
    vote_2 = union(2)
    vote_3 = union(3)
    vote_4 = union(4)
    vote_5 = union(5)
    vote_6 = union(6)
    vote_7 = union(7)
    vote_8 = union(8)
    
    votes = {1: vote_1, 2: vote_2, 3: vote_3, 4: vote_4, 5: vote_5, 6: vote_6, 7: vote_7, 8: vote_8}
    cand = max(votes.values())
    for a, b in votes.items():
        if b == cand:
            lst_cand.append(a)
            
    print(votes)
    
    #Si hay varios candidatos con igual ponderación se escoge uno al azar
    random.shuffle(lst_cand)
    return lst_cand[0]

# %%
def choise_player():
    '''
    Sirve para determinar al azar con que ficha juega cada quién
    '''
    car = 0
    
    co_2 = int(input(f'Choise the column for the PLAYER, he plays with O '))
    col_2 = (co_2 * 20) - 19
    while not static_var.board[col_2] == ' ':#
        col_2 += 1
        car += 1
    else:
        if car > 8:
            other = int(input("This column it's full, please choise other "))
            return other
        else:
            static_var.f_board(static_var.player , col_2)
            static_var.f_roun()

# %%
import time
def put_fall():
    '''
    Está función se encarga de regular los turnos(así como llamar toda la sección procesamiento máquina cuando es su turno)
    Y que la ficha aparezca en cada columna en el punto vacío más bajo de está
    '''

    if static_var.roun % 2 == 0:
        time.sleep(1)
        co_1 = the_election()
        col_1 = (co_1 * 20) - 19

        while not static_var.board[col_1] == ' ':#
            col_1 += 1

        else:
            if col_1 in states:
                static_var.f_board(static_var.computer, col_1)
                static_var.f_bor_scene(static_var.computer, col_1)
                static_var.f_roun()

    elif static_var.roun % 2 == 1:
        co_2 = int(input(f'Choise the column you plays with {static_var.player} '))
        col_2 = (co_2 * 20) - 19

        while not static_var.board[col_2] == ' ':#
            col_2 += 1

        else:
            #if col_2 in states:
            static_var.f_board(static_var.player, col_2)
            static_var.f_bor_scene(static_var.player, col_2)
            static_var.f_roun()

# %%
playing = None

# %%
def main():
    '''
    Aquí se integra todo lo anterior mencionado
    '''
    yes_sir = ['yes', 'ok', 'yes please', 'y', 's', 'si']
    playing = True
    the_list_comp = [ ]
    the_list_play = [ ]
    
    while True:
        start()
        static_var.cicle_or_cross()
        while playing == True:
            revange = 'No'
            again = 'No'
            screen(static_var.board)
            put_fall()
            print(static_var.the_marker(static_var.board))
            
            print(screen(static_var.board_scene))
            print('I am the screen for do scenes')
            
           
    
            for lst in static_var.the_marker(static_var.board):
                for ele in lst:
                    if ele == static_var.computer: #+ ' ':
                        the_list_comp.append(ele)
                        the_list_play = [ ]
                        if len(the_list_comp) >= 4:
                            screen(static_var.board)

                            revange = input('POUI 4! You loose :( \n\nWould you want to play again? ')
                            playing = False

                    elif ele == static_var.player: #+ ' ':
                        the_list_play.append(ele)
                        the_list_comp = [ ]
                        if len(the_list_play) >= 4:
                            screen(static_var.board)

                            again = input('POUI 4! YOU WIN :D !!! \n\nWould you want to play again? ')
                            playing = False
                    else:
                        the_list_play = [ ]
                        the_list_comp = [ ]
        if revange in yes_sir or again in yes_sir:
            start()
            static_var.cicle_or_cross()
            playing = True
            continue
        else:
            print('Thanks for playing')
            break
            
                
                
main()
# Out:
#  1  2  3  4  5  6  7  8
# |  |  |  |  |  |  |  |  |
# ------------------------
# |  |  |  |  |  |  |  |  |
# ------------------------
# |  |  |  |  |  |  |  |  |
# ------------------------
# |  |  |  |  |  |  |  |  |
# ------------------------
# |  |  |  |  |  |  |  |  |
# ------------------------
# |  |  |  |  |  |  |  |  |
# ------------------------
# |  |  |  |  |  |  |  |  |
# ------------------------
# |  |  |  |  |  |  |  |O |
# ------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     883             try:
# --> 884                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     885             except Exception:
#
# ...

# %%
#Si deseas reiniciar el juego interrumpe el kernel y ejecuta está linea
#aun no entiendo porque los siguientes juegos, despues del primero los errores de desciones se vuelven más evidentes
static_var.f_start()
static_var.f_start_scene()
